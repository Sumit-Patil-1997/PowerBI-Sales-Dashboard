# %% [markdown]
#  # <span style="background-color: #EB824F; padding: 10px"><strong>       Super Store Sales Dashboard      </strong></span>

# %% [markdown]
# # • OBJECTIVE

# %% [markdown]
# # • To contribute to the success of a business by utilizing data analysis techniques, specifically focusing on time series analysis, to provide valuable insights and accurate sales forecasting.

# %%
from skimage import io
import matplotlib.pyplot as plt
img = io.imread("C:\\Users\\sumit\\Downloads\\Sales_Dashboard.png")
plt.figure(dpi=800)
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
img = io.imread("C:\\Users\\sumit\\Downloads\\Sales_dashboard2.png")
plt.figure(dpi=400)
plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
#  # <span style="background-color: #EB824F; padding: 10px"><strong>       Project Learnings     </strong></span>

# %% [markdown]
# # • Created interactive dashboard to track and analyze  sales data

# %% [markdown]
# # • Used complex parameters to drill down in worksheet and customization using filters and slicers

# %% [markdown]
# # • Created connections, join new tables, calculations to manipulate data and enable user driven parameters for visualizations

# %% [markdown]
# # • Used different types of customized visualization (bar chart, pie chart, donut chart, clustered bar chart, funnel chat,line chart, area chart, map, slicers, etc)

# %% [markdown]
# # •Incorporated data analysis techniques, specializing in time series analysis, to deliver valuable insights, accurate sales forecasting, and interactive dashboard creation, driving business success.
